# %%
import pandas as pd
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import cross_val_score

# Load the CSV file containing features and labels
data = pd.read_csv('ravdess_features.csv')

# Separate features and labels
X = data.drop(columns=['filename', 'emotion'])
y = data['emotion']  

# Convert categorical labels into numeric values
label_encoder = LabelEncoder()
y_encoded = label_encoder.fit_transform(y)  

# Standardize the features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)  

# Reshape data for CNN (1D convolution)
X_scaled_reshaped = np.expand_dims(X_scaled, axis=-1)

# Define the CNN model
def create_cnn_model(input_shape, num_classes, learning_rate=0.001):
    model = models.Sequential()
    model.add(layers.Conv1D(64, 3, activation='relu', input_shape=input_shape))
    model.add(layers.MaxPooling1D(2))
    model.add(layers.Conv1D(128, 3, activation='relu'))
    model.add(layers.MaxPooling1D(2))
    model.add(layers.Dropout(0.5))  # Dropout to prevent overfitting
    model.add(layers.Flatten())
    model.add(layers.Dense(128, activation='relu'))
    model.add(layers.Dropout(0.5))  # Dropout after Dense layer
    model.add(layers.Dense(64, activation='relu'))
    model.add(layers.Dense(num_classes, activation='softmax'))

    optimizer = Adam(learning_rate=learning_rate)
    model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    
    return model

# Perform K-fold cross-validation
kfold = KFold(n_splits=5, shuffle=True, random_state=42)
fold_no = 1
accuracies = []

for train_idx, val_idx in kfold.split(X_scaled_reshaped, y_encoded):
    X_train, X_val = X_scaled_reshaped[train_idx], X_scaled_reshaped[val_idx]
    y_train, y_val = y_encoded[train_idx], y_encoded[val_idx]
    
    # Create model
    model = create_cnn_model((X_train.shape[1], 1), len(label_encoder.classes_))
    
    # Train model
    history = model.fit(X_train, y_train, epochs=20, batch_size=32, validation_data=(X_val, y_val), verbose=1)
    
    # Evaluate model on validation set
    val_loss, val_acc = model.evaluate(X_val, y_val, verbose=0)
    print(f"Fold {fold_no} - Validation accuracy: {val_acc:.4f}")
    accuracies.append(val_acc)
    
    fold_no += 1

# Output the cross-validation results
print(f"Cross-validation accuracies: {accuracies}")
print(f"Mean accuracy: {np.mean(accuracies):.4f} ± {np.std(accuracies):.4f}")

# Final model training on the full training set
final_model = create_cnn_model((X_scaled_reshaped.shape[1], 1), len(label_encoder.classes_))
history = final_model.fit(X_scaled_reshaped, y_encoded, epochs=20, batch_size=32, validation_split=0.2, verbose=1)

# Plot training history
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# Final evaluation on test data
test_loss, test_acc = final_model.evaluate(X_scaled_reshaped, y_encoded, verbose=2)
print(f"Test accuracy: {test_acc:.4f}")

final_model.summary()
# Out:
# Epoch 1/20
# /Users/mariaalsalem/anaconda3/lib/python3.11/site-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.1676 - loss: 2.0643 - val_accuracy: 0.3333 - val_loss: 1.8006
# Epoch 2/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.2764 - loss: 1.8371 - val_accuracy: 0.3646 - val_loss: 1.6304
# Epoch 3/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3424 - loss: 1.6886 - val_accuracy: 0.4306 - val_loss: 1.5489
# Epoch 4/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3837 - loss: 1.6220 - val_accuracy: 0.4722 - val_loss: 1.4788
# Epoch 5/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4422 - loss: 1.5060 - val_accuracy: 0.4132 - val_loss: 1.4383
# Epoch 6/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4727 - loss: 1.4068 - val_accuracy: 0.4826 - val_loss: 1.4289
# Epoch 7/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4981 - loss: 1.3652 - val_accuracy: 0.4896 - val_loss: 1.3775
# Epoch 8/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5107 - loss: 1.2888 - val_accuracy: 0.5000 - val_loss: 1.3385
# Epoch 9/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5511 - loss: 1.1952 - val_accuracy: 0.5139 - val_loss: 1.3209
# Epoch 10/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5281 - loss: 1.2203 - val_accuracy: 0.5278 - val_loss: 1.2600
# Epoch 11/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6034 - loss: 1.0926 - val_accuracy: 0.5278 - val_loss: 1.3005
# Epoch 12/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6043 - loss: 1.1015 - val_accuracy: 0.5382 - val_loss: 1.2560
# Epoch 13/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6151 - loss: 1.0051 - val_accuracy: 0.5243 - val_loss: 1.2791
# Epoch 14/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6120 - loss: 1.0436 - val_accuracy: 0.5278 - val_loss: 1.2540
# Epoch 15/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6615 - loss: 0.9433 - val_accuracy: 0.5486 - val_loss: 1.2804
# Epoch 16/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6213 - loss: 0.9805 - val_accuracy: 0.5660 - val_loss: 1.2584
# Epoch 17/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7000 - loss: 0.8495 - val_accuracy: 0.5903 - val_loss: 1.2371
# Epoch 18/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6408 - loss: 0.9415 - val_accuracy: 0.5764 - val_loss: 1.2400
# Epoch 19/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6959 - loss: 0.8699 - val_accuracy: 0.5694 - val_loss: 1.2330
# Epoch 20/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7132 - loss: 0.7741 - val_accuracy: 0.5590 - val_loss: 1.2700
# Fold 1 - Validation accuracy: 0.5590
# Epoch 1/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.1886 - loss: 2.0121 - val_accuracy: 0.2882 - val_loss: 1.7940
# Epoch 2/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3203 - loss: 1.7776 - val_accuracy: 0.3368 - val_loss: 1.6997
# Epoch 3/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3990 - loss: 1.5816 - val_accuracy: 0.3438 - val_loss: 1.6867
# Epoch 4/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.3911 - loss: 1.5685 - val_accuracy: 0.4201 - val_loss: 1.6052
# Epoch 5/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4647 - loss: 1.4353 - val_accuracy: 0.4375 - val_loss: 1.6015
# Epoch 6/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4496 - loss: 1.4218 - val_accuracy: 0.4375 - val_loss: 1.5755
# Epoch 7/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5142 - loss: 1.2668 - val_accuracy: 0.4653 - val_loss: 1.5944
# Epoch 8/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5372 - loss: 1.2133 - val_accuracy: 0.5208 - val_loss: 1.4812
# Epoch 9/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5574 - loss: 1.1823 - val_accuracy: 0.5312 - val_loss: 1.4859
# Epoch 10/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6174 - loss: 1.0685 - val_accuracy: 0.5486 - val_loss: 1.4723
# Epoch 11/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6114 - loss: 1.0610 - val_accuracy: 0.4861 - val_loss: 1.6208
# Epoch 12/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6037 - loss: 1.0603 - val_accuracy: 0.5312 - val_loss: 1.5285
# Epoch 13/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6516 - loss: 0.9383 - val_accuracy: 0.5521 - val_loss: 1.5726
# Epoch 14/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6342 - loss: 0.9462 - val_accuracy: 0.5278 - val_loss: 1.5313
# Epoch 15/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6738 - loss: 0.9035 - val_accuracy: 0.5486 - val_loss: 1.5738
# Epoch 16/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.6683 - loss: 0.8975 - val_accuracy: 0.5243 - val_loss: 1.6983
# Epoch 17/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6980 - loss: 0.8804 - val_accuracy: 0.5382 - val_loss: 1.6210
# Epoch 18/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.7035 - loss: 0.7936 - val_accuracy: 0.5556 - val_loss: 1.6763
# Epoch 19/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7015 - loss: 0.7907 - val_accuracy: 0.5799 - val_loss: 1.6429
# Epoch 20/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.7148 - loss: 0.7547 - val_accuracy: 0.5764 - val_loss: 1.6333
# Fold 2 - Validation accuracy: 0.5764
# Epoch 1/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.2024 - loss: 2.0094 - val_accuracy: 0.3333 - val_loss: 1.7698
# Epoch 2/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3027 - loss: 1.8066 - val_accuracy: 0.3958 - val_loss: 1.6655
# Epoch 3/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.3715 - loss: 1.6316 - val_accuracy: 0.3785 - val_loss: 1.6286
# Epoch 4/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4053 - loss: 1.5601 - val_accuracy: 0.4201 - val_loss: 1.5497
# Epoch 5/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4723 - loss: 1.4366 - val_accuracy: 0.4583 - val_loss: 1.4383
# Epoch 6/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4700 - loss: 1.4142 - val_accuracy: 0.4340 - val_loss: 1.4284
# Epoch 7/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5146 - loss: 1.3296 - val_accuracy: 0.4340 - val_loss: 1.3858
# Epoch 8/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5080 - loss: 1.3008 - val_accuracy: 0.4479 - val_loss: 1.3998
# Epoch 9/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5482 - loss: 1.1668 - val_accuracy: 0.4965 - val_loss: 1.3015
# Epoch 10/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5541 - loss: 1.1717 - val_accuracy: 0.5278 - val_loss: 1.2775
# Epoch 11/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6034 - loss: 1.0691 - val_accuracy: 0.5278 - val_loss: 1.2491
# Epoch 12/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6358 - loss: 1.0418 - val_accuracy: 0.5521 - val_loss: 1.2390
# Epoch 13/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6258 - loss: 1.0718 - val_accuracy: 0.5278 - val_loss: 1.2019
# Epoch 14/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6650 - loss: 0.9793 - val_accuracy: 0.6076 - val_loss: 1.1361
# Epoch 15/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6481 - loss: 0.9908 - val_accuracy: 0.5694 - val_loss: 1.1422
# Epoch 16/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7039 - loss: 0.8885 - val_accuracy: 0.5938 - val_loss: 1.1251
# Epoch 17/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6752 - loss: 0.8928 - val_accuracy: 0.5660 - val_loss: 1.1748
# Epoch 18/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7279 - loss: 0.7947 - val_accuracy: 0.5833 - val_loss: 1.1402
# Epoch 19/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.7480 - loss: 0.7274 - val_accuracy: 0.6111 - val_loss: 1.1034
# Epoch 20/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6881 - loss: 0.8480 - val_accuracy: 0.6076 - val_loss: 1.0793
# Fold 3 - Validation accuracy: 0.6076
# Epoch 1/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.1697 - loss: 2.0516 - val_accuracy: 0.3472 - val_loss: 1.7505
# Epoch 2/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.2952 - loss: 1.8367 - val_accuracy: 0.4167 - val_loss: 1.6033
# Epoch 3/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3477 - loss: 1.7218 - val_accuracy: 0.4931 - val_loss: 1.4796
# Epoch 4/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.3785 - loss: 1.6071 - val_accuracy: 0.5035 - val_loss: 1.3859
# Epoch 5/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4132 - loss: 1.5261 - val_accuracy: 0.5035 - val_loss: 1.3379
# Epoch 6/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4349 - loss: 1.4770 - val_accuracy: 0.5312 - val_loss: 1.2688
# Epoch 7/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4514 - loss: 1.4296 - val_accuracy: 0.5278 - val_loss: 1.2476
# Epoch 8/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4753 - loss: 1.3384 - val_accuracy: 0.5590 - val_loss: 1.1830
# Epoch 9/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.5417 - loss: 1.2265 - val_accuracy: 0.5660 - val_loss: 1.1774
# Epoch 10/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.5550 - loss: 1.2244 - val_accuracy: 0.5903 - val_loss: 1.0701
# Epoch 11/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5749 - loss: 1.1149 - val_accuracy: 0.5799 - val_loss: 1.0777
# Epoch 12/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5720 - loss: 1.1118 - val_accuracy: 0.6111 - val_loss: 1.0280
# Epoch 13/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6006 - loss: 1.0516 - val_accuracy: 0.6354 - val_loss: 1.0332
# Epoch 14/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6309 - loss: 1.0654 - val_accuracy: 0.6111 - val_loss: 1.0115
# Epoch 15/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6316 - loss: 0.9751 - val_accuracy: 0.6458 - val_loss: 1.0096
# Epoch 16/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.6314 - loss: 0.9870 - val_accuracy: 0.6250 - val_loss: 1.0395
# Epoch 17/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6575 - loss: 0.9288 - val_accuracy: 0.6424 - val_loss: 0.9796
# Epoch 18/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6686 - loss: 0.8641 - val_accuracy: 0.6250 - val_loss: 1.0110
# Epoch 19/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6772 - loss: 0.8671 - val_accuracy: 0.6389 - val_loss: 1.0092
# Epoch 20/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6834 - loss: 0.8680 - val_accuracy: 0.6042 - val_loss: 1.0332
# Fold 4 - Validation accuracy: 0.6042
# Epoch 1/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.1691 - loss: 2.0366 - val_accuracy: 0.2778 - val_loss: 1.8543
# Epoch 2/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3270 - loss: 1.7793 - val_accuracy: 0.3229 - val_loss: 1.7556
# Epoch 3/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4099 - loss: 1.6106 - val_accuracy: 0.3507 - val_loss: 1.6981
# Epoch 4/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4261 - loss: 1.5621 - val_accuracy: 0.4340 - val_loss: 1.5825
# Epoch 5/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.4561 - loss: 1.4842 - val_accuracy: 0.4410 - val_loss: 1.5487
# Epoch 6/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4640 - loss: 1.3989 - val_accuracy: 0.4410 - val_loss: 1.5247
# Epoch 7/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5280 - loss: 1.3099 - val_accuracy: 0.4688 - val_loss: 1.4612
# Epoch 8/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5526 - loss: 1.2592 - val_accuracy: 0.4792 - val_loss: 1.4265
# Epoch 9/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5667 - loss: 1.1978 - val_accuracy: 0.5035 - val_loss: 1.4042
# Epoch 10/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.5571 - loss: 1.1478 - val_accuracy: 0.5278 - val_loss: 1.3624
# Epoch 11/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5910 - loss: 1.1121 - val_accuracy: 0.5382 - val_loss: 1.3840
# Epoch 12/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6053 - loss: 1.0817 - val_accuracy: 0.5347 - val_loss: 1.3593
# Epoch 13/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.6125 - loss: 1.0088 - val_accuracy: 0.5347 - val_loss: 1.3725
# Epoch 14/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6854 - loss: 0.9211 - val_accuracy: 0.5486 - val_loss: 1.3121
# Epoch 15/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6745 - loss: 0.9232 - val_accuracy: 0.5590 - val_loss: 1.2900
# Epoch 16/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6890 - loss: 0.8558 - val_accuracy: 0.5382 - val_loss: 1.3291
# Epoch 17/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6899 - loss: 0.8393 - val_accuracy: 0.5590 - val_loss: 1.3273
# Epoch 18/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7002 - loss: 0.8776 - val_accuracy: 0.5729 - val_loss: 1.3107
# Epoch 19/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7313 - loss: 0.7643 - val_accuracy: 0.5868 - val_loss: 1.3391
# Epoch 20/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7192 - loss: 0.7530 - val_accuracy: 0.5868 - val_loss: 1.3615
# Fold 5 - Validation accuracy: 0.5868
# Cross-validation accuracies: [0.5590277910232544, 0.5763888955116272, 0.6076388955116272, 0.6041666865348816, 0.5868055820465088]
# Mean accuracy: 0.5868 ± 0.0180
# Epoch 1/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.1799 - loss: 2.0497 - val_accuracy: 0.2674 - val_loss: 1.8632
# Epoch 2/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.3025 - loss: 1.8379 - val_accuracy: 0.3785 - val_loss: 1.6642
# Epoch 3/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.3571 - loss: 1.6782 - val_accuracy: 0.3924 - val_loss: 1.5943
# Epoch 4/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.4063 - loss: 1.6063 - val_accuracy: 0.4444 - val_loss: 1.5318
# Epoch 5/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.4503 - loss: 1.4883 - val_accuracy: 0.4444 - val_loss: 1.4844
# Epoch 6/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4617 - loss: 1.4255 - val_accuracy: 0.4514 - val_loss: 1.4290
# Epoch 7/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4835 - loss: 1.3670 - val_accuracy: 0.4757 - val_loss: 1.4302
# Epoch 8/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5415 - loss: 1.2727 - val_accuracy: 0.4549 - val_loss: 1.4371
# Epoch 9/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5162 - loss: 1.2298 - val_accuracy: 0.4479 - val_loss: 1.3968
# Epoch 10/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5541 - loss: 1.1563 - val_accuracy: 0.4826 - val_loss: 1.3835
# Epoch 11/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.5989 - loss: 1.0547 - val_accuracy: 0.4792 - val_loss: 1.4064
# Epoch 12/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5992 - loss: 1.0629 - val_accuracy: 0.4861 - val_loss: 1.4004
# Epoch 13/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6445 - loss: 0.9852 - val_accuracy: 0.4757 - val_loss: 1.5223
# Epoch 14/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.6657 - loss: 0.9426 - val_accuracy: 0.4618 - val_loss: 1.4852
# Epoch 15/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.6451 - loss: 0.9813 - val_accuracy: 0.4965 - val_loss: 1.5279
# Epoch 16/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6744 - loss: 0.9327 - val_accuracy: 0.4826 - val_loss: 1.4705
# Epoch 17/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.6938 - loss: 0.8477 - val_accuracy: 0.5035 - val_loss: 1.5124
# Epoch 18/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.7160 - loss: 0.7707 - val_accuracy: 0.4965 - val_loss: 1.5100
# Epoch 19/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7398 - loss: 0.7458 - val_accuracy: 0.4375 - val_loss: 1.6474
# Epoch 20/20
# 36/36 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7216 - loss: 0.7638 - val_accuracy: 0.4861 - val_loss: 1.5966
# 45/45 - 0s - 3ms/step - accuracy: 0.8201 - loss: 0.6380
# Test accuracy: 0.8201
# Model: "sequential_66"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_145 (Conv1D)             │ (None, 86, 64)         │           256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_144               │ (None, 43, 64)         │             0 │
# │ (MaxPooling1D)                  │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_146 (Conv1D)             │ (None, 41, 128)        │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_145               │ (None, 20, 128)        │             0 │
# │ (MaxPooling1D)                  │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_77 (Dropout)            │ (None, 20, 128)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_65 (Flatten)            │ (None, 2560)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_197 (Dense)               │ (None, 128)            │       327,808 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_78 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_198 (Dense)               │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_199 (Dense)               │ (None, 8)              │           520 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,084,634 (4.14 MB)
#  Trainable params: 361,544 (1.38 MB)
#  Non-trainable params: 0 (0.00 B)
#  Optimizer params: 723,090 (2.76 MB)
